# %% [markdown]
# <a href="https://colab.research.google.com/github/Maraka-Varshith-Reddy/DSA0203/blob/main/cv_lab_11.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#EXPERIMENT 11
import cv2
import numpy as np
from google.colab.patches import cv2_imshow

img = cv2.imread("sloka.jpg")

rows, cols = img.shape[:2]

pts1 = np.float32([[50,50], [200,50], [50,200]])
pts2 = np.float32([[10,100], [200,50], [100,250]])

matrix = cv2.getAffineTransform(pts1, pts2)

result = cv2.warpAffine(img, matrix, (cols, rows))

print("Original Image")
cv2_imshow(img)

print("Affine Transformed Image")
cv2_imshow(result)

cv2.imwrite("/content/Affine_Image.jpg", result)

print("Image saved successfully")
# Out:
# Original Image
# <PIL.Image.Image image mode=RGB size=1200x675>
# Affine Transformed Image
# <PIL.Image.Image image mode=RGB size=1200x675>
# Image saved successfully
