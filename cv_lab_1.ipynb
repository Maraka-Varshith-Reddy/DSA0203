# %% [markdown]
# <a href="https://colab.research.google.com/github/Maraka-Varshith-Reddy/DSA0203/blob/main/cv_lab_1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import cv2
from google.colab import files
from google.colab.patches import cv2_imshow

image = cv2.imread("image_3b8a5190.png")

if image is None:
    print("upload the image")
else:
    gray = cv2.cvtColor(image, cv2.COLOR_BGR2GRAY)

    cv2.imwrite("grayscale_image.jpg", gray)

    print("Grayscale Image")
    cv2_imshow(gray)
# Out:
# Grayscale Image
# <PIL.Image.Image image mode=L size=1365x768>
