# %% [markdown]
# <a href="https://colab.research.google.com/github/Maraka-Varshith-Reddy/DSA0203/blob/main/cv_lab_10.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import cv2
from google.colab.patches import cv2_imshow

image = cv2.imread("sloka.jpg")

if image is None:
    print("Unable to read image")
else:
    width = image.shape[1]
    height = image.shape[0]

    print("Image Width:", width)
    print("Image Height:", height)

    cv2_imshow(image)

    cv2.imwrite("/content/Saved_Image.jpg", image)

    print("Image saved successfully.")
# Out:
# Image Width: 1200
# Image Height: 675
# <PIL.Image.Image image mode=RGB size=1200x675>
# Image saved successfully.
