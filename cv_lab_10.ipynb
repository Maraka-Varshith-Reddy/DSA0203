# %% [markdown]
# <a href="https://colab.research.google.com/github/Maraka-Varshith-Reddy/DSA0203/blob/main/cv_lab_10.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np

tx, ty = 100, 50

M = np.float32([[1, 0, tx],
                [0, 1, ty]])

translated_image = cv2.warpAffine(image, M, (width, height))

cv2_imshow(translated_image)
print(f"Image translated by {tx} pixels horizontally and {ty} pixels vertically.")
# Out:
# <PIL.Image.Image image mode=RGB size=1200x675>
# Image translated by 100 pixels horizontally and 50 pixels vertically.
