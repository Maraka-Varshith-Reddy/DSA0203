# %% [markdown]
# <a href="https://colab.research.google.com/github/Maraka-Varshith-Reddy/DSA0203/blob/main/cv_lab_5.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import cv2
import numpy as np
from google.colab.patches import cv2_imshow

img = cv2.imread("lord ganesh (1).jpg")
if img is None:
    print("Error: Could not load image. Make sure 'lord ganesh (1).jpg' exists in the current directory.")
else:

    gray_image = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)

    kernel = cv2.getStructuringElement(cv2.MORPH_RECT, (5, 5))

    eroded_image = cv2.erode(gray_image, kernel, iterations=1)

    cv2.imwrite("eroded_image.jpg", eroded_image)


    print("Original Image:")
    cv2_imshow(img)
    print("Eroded Image:")
    cv2_imshow(eroded_image)
# Out:
# Original Image:
# <PIL.Image.Image image mode=RGB size=1280x720>
# Eroded Image:
# <PIL.Image.Image image mode=L size=1280x720>
