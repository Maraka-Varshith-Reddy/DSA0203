# %% [markdown]
# <a href="https://colab.research.google.com/github/Maraka-Varshith-Reddy/DSA0203/blob/main/cv_lab_19.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import cv2
import numpy as np
from google.colab.patches import cv2_imshow
img=cv2.imread("lord ganesh.jpg")
sobelx=cv2.Sobel(img,cv2.CV_64F,1,0,ksize=3)
sobely=cv2.Sobel(img,cv2.CV_64F,0,1,ksize=3)
cv2_imshow(sobelx)
cv2_imshow(sobely)
edges=cv2.addWeighted(sobelx,0.5,sobely,0.5,0)
cv2_imshow(edges)
# Out:
# <PIL.Image.Image image mode=RGB size=1280x720>
# <PIL.Image.Image image mode=RGB size=1280x720>
# <PIL.Image.Image image mode=RGB size=1280x720>
