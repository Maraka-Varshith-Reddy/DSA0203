# %% [markdown]
# <a href="https://colab.research.google.com/github/Maraka-Varshith-Reddy/DSA0203/blob/main/cv_lab_4.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import cv2
import numpy as np
from google.colab.patches import cv2_imshow

img=cv2.imread("image_3b8a5190.png")
kernel=np.ones((5,5),np.uint8)
dilated_img=cv2.dilate(img,kernel,iterations=1)
cv2.imwrite('dilated_img.jpg',dilated_img)
cv2_imshow(dilated_img)
# Out:
# <PIL.Image.Image image mode=RGB size=1365x768>
